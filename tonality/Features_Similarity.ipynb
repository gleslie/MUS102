# %% [markdown]
# <h1>The Bregman Music and Audio Toolkit</h1>
# <h2>Dartmouth College</h2>

# %%
execfile('1_features.py')

# %%
execfile('2_testsignal.py')
# Out:
# Example 1: sinusoid
# Period size is 64 , Buffer size is 22050
# Example 2: harmonics
# Period size is 64 , Buffer size is 22050
# Example 3a: Shepard tones, Deutch's Tri-Tone Paradox
# Period size is 64 , Buffer size is 22050
# Example 3b: Shepard tones as gliding Risset tones
# Period size is 64 , Buffer size is 22050
# Example 4: noise band, bandwidth-expanded sinusoid
# Period size is 64 , Buffer size is 22050
# Example 5: noise-band rhythm
# Period size is 64 , Buffer size is 24000

# %%
execfile('3_similarity.py')
# Out:
# Original sound
# Period size is 64 , Buffer size is 22050
# Re-sampled sound
# Period size is 64 , Buffer size is 22050
# Phase Vocoder Resynthesis... 16384 8192 2205 1
# Aligned sound: Features.inverse(F.X[:,warp_idx])
# Period size is 64 , Buffer size is 22050

# %%
execfile('5_plca.py')
# Out:
# Example 1: Standard PLCA with cqft features split into n=4 components
# Period size is 32 , Buffer size is 22050
# Period size is 32 , Buffer size is 22050
# Period size is 32 , Buffer size is 22050
# Period size is 32 , Buffer size is 22050
